# %% [markdown]
# # Download data

# %% [markdown]
# # 1. Imports

# %% [markdown]
# ## 1.1 Packages

# %%
import pandas as pd
import requests

# %% [markdown]
# ## 1.2 Options

# %%
url = "https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/velib-disponibilite-en-temps-reel/records?refine=nom_arrondissement_communes%3A%22Paris%22&refine=nom_arrondissement_communes%3A%22Levallois-Perret%22&refine=nom_arrondissement_communes%3A%22Puteaux%22&refine=nom_arrondissement_communes%3A%22Suresnes%22&refine=nom_arrondissement_communes%3A%22Boulogne-Billancourt%22&refine=nom_arrondissement_communes%3A%22Clichy%22"

# %% [markdown]
# # 2. Data

# %%
response = requests.get(url).json()
df = pd.DataFrame(response['results'])

# %%
df
# Out:
#   stationcode                           name is_installed  capacity  \
# 0       16107  Benjamin Godard - Victor Hugo          OUI        35
# 1        9020             Toudouze - Clauzel          OUI        21
# 2       13007             Le Brun - Gobelins          OUI        48
# 3        7002                Vaneau - Sèvres          OUI        35
# 4       21010               Silly - Galliéni          OUI        25
# 5        7003               Square Boucicaut          OUI        60
# 6       17041   Guersant - Gouvion-Saint-Cyr          OUI        36
# 7       11025              Froment - Bréguet          OUI        43
# 8       15047            Morillons - Dantzig          OUI        52
# 9       17026     Jouffroy d'Abbans - Wagram          OUI        40
#
#    numdocksavailable  numbikesavailable  mechanical  ebike is_renting  \
# 0                 33                  2           1      1        OUI
# 1                 20                  1           0      1        OUI
# 2                 29                 19          14      5        OUI
# 3                 14                 19          17      2        OUI
# 4                  4                 19          16      3        OUI
# 5                 55                  1           0      1        OUI
# 6                 13                 22          19      3        OUI
# 7                 29                 11           9      2        OUI
# 8                 15                 37          27     10        OUI
# 9                 29                 11           9      2        OUI
#
#   is_returning                    duedate  \
# 0          OUI  2024-09-05T05:43:52+00:00
# 1          OUI  2024-09-05T05:47:30+00:00
# 2          OUI  2024-09-05T05:47:04+00:00
# 3          OUI  2024-09-05T05:48:41+00:00
# 4          OUI  2024-09-05T05:48:47+00:00
# 5          OUI  2024-09-05T05:45:25+00:00
# 6          OUI  2024-09-05T05:47:59+00:00
# 7          OUI  2024-09-05T05:46:52+00:00
# 8          OUI  2024-09-05T05:47:20+00:00
# 9          OUI  2024-09-05T05:46:27+00:00
#
#                                      coordonnees_geo  \
# 0                {'lon': 2.275725, 'lat': 48.865983}
# 1  {'lon': 2.3373600840568547, 'lat': 48.87929591...
# 2   {'lon': 2.3534681351338, 'lat': 48.835092787824}
# 3   {'lon': 2.3204218259346, 'lat': 48.848563233059}
# 4   {'lon': 2.2325500845909, 'lat': 48.835583838706}
# 5  {'lon': 2.325061820447445, 'lat': 48.851296433...
# 6  {'lon': 2.287667370814871, 'lat': 48.882877751...
# 7  {'lon': 2.37289470306807, 'lat': 48.8570414504...
# 8  {'lon': 2.299380004405976, 'lat': 48.833101499...
# 9    {'lon': 2.301132157445, 'lat': 48.881973298352}
#
#   nom_arrondissement_communes code_insee_commune
# 0                       Paris              75056
# 1                       Paris              75056
# 2                       Paris              75056
# 3                       Paris              75056
# 4        Boulogne-Billancourt              92012
# 5                       Paris              75056
# 6                       Paris              75056
# 7                       Paris              75056
# 8                       Paris              75056
# 9                       Paris              75056
