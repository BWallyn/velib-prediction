# %%
import pandas as pd

# %%
path_data = "https://data.education.gouv.fr/api/explore/v2.1/catalog/datasets/fr-en-calendrier-scolaire/exports/csv?lang=fr&timezone=Europe%2FParis&use_labels=true&delimiter=%3B"
df_holidays = pd.read_csv(path_data, sep=";").sort_values(by="Date de début")
# Select only metropolitan France dates
df_holidays = df_holidays[df_holidays["Zones"].isin(["Zone A", "Zone B", "Zone C"])]
# Drop duplicates between same zones and dates
df_holidays.drop_duplicates(subset=["Zones", "Date de début"], inplace=True)
# Change types
df_holidays["Date de début"] = pd.to_datetime(df_holidays["Date de début"].str[:10], format="%Y-%m-%d")
df_holidays["Date de fin"] = pd.to_datetime(df_holidays["Date de fin"].str[:10], format="%Y-%m-%d")
df_holidays.rename(columns={"Date de début": "date_begin", "Date de fin": "date_end"}, inplace=True)

# %%
df_holidays
# Out:
#                    Description Population date_begin   date_end  \
# 1704  Vacances de la Toussaint          - 2017-10-21 2017-11-06
# 1507  Vacances de la Toussaint          - 2017-10-21 2017-11-06
# 1810  Vacances de la Toussaint          - 2017-10-21 2017-11-06
# 824           Vacances de Noël          - 2017-12-23 2018-01-08
# 923           Vacances de Noël          - 2017-12-23 2018-01-08
# ...                        ...        ...        ...        ...
# 1500       Pont de l'Ascension          - 2026-05-14 2026-05-18
# 688        Pont de l'Ascension          - 2026-05-14 2026-05-18
# 216   Début des Vacances d'Été          - 2026-07-04 2026-07-04
# 1566  Début des Vacances d'Été          - 2026-07-04 2026-07-04
# 501   Début des Vacances d'Été          - 2026-07-04 2026-07-04
#
#           Académies   Zones annee_scolaire
# 1704        Limoges  Zone A      2017-2018
# 1507     Versailles  Zone C      2017-2018
# 1810     Strasbourg  Zone B      2017-2018
# 824        Poitiers  Zone A      2017-2018
# 923   Orléans-Tours  Zone B      2017-2018
# ...             ...     ...            ...
# 1500      Normandie  Zone B      2025-2026
# 688        Toulouse  Zone C      2025-2026
# 216            Nice  Zone B      2025-2026
# 1566       Toulouse  Zone C      2025-2026
# 501        Poitiers  Zone A      2025-2026
#
# [159 rows x 7 columns]

# %%
df_holidays.dtypes
# Out:
# Description               object
# Population                object
# date_begin        datetime64[ns]
# date_end          datetime64[ns]
# Académies                 object
# Zones                     object
# annee_scolaire            object
# dtype: object

# %%
df = pd.read_parquet("../data/02_intermediate/df_data_engineered.parquet")

# %%
df.sample(2)
# Out:
#     stationcode  is_installed  capacity  numdocksavailable  numbikesavailable  \
# 139       13001          True      18.0                 15                  2
# 433       11041          True      43.0                 31                 11
#
#      mechanical  ebike  is_renting  is_returning             duedate  \
# 139           1      1        True          True 2024-08-19 09:04:46
# 433           9      2        True          True 2024-08-19 09:04:42
#
#     code_insee_commune        date
# 139              75056  2024-08-19
# 433              75056  2024-08-19

# %%
df.dtypes
# Out:
# stationcode                   object
# is_installed                    bool
# capacity                     float64
# numdocksavailable              int64
# numbikesavailable              int64
# mechanical                     int64
# ebike                          int64
# is_renting                      bool
# is_returning                    bool
# duedate               datetime64[ms]
# code_insee_commune            object
# date                          object
# dtype: object

# %%
df_test = pd.read_parquet("../data/03_primary/df_test_w_date_feat.parquet")

# %%
df_test.sample(2)
# Out:
#     stationcode  is_installed  capacity  numdocksavailable  numbikesavailable  \
# 969        4103          True      25.0                  2                 22
# 363       20040          True      26.0                 24                  2
#
#      mechanical  ebike  is_renting  is_returning             duedate  \
# 969          10     12        True          True 2024-08-19 09:02:58
# 363           1      1        True          True 2024-08-19 09:03:15
#
#     code_insee_commune        date  duedate_year  duedate_month  duedate_day  \
# 969              75056  2024-08-19          2024              8           19
# 363              75056  2024-08-19          2024              8           19
#
#      duedate_weekday  duedate_weekend
# 969                0                0
# 363                0                0

# %%
import sys
sys.path.append("../src/velib_prediction/pipelines/feature_engineering")
from nodes import add_holidays_period

# %%
add_holidays_period(df_test, df_holidays, feat_date="date", zone="Zone A")
# Out:
#      stationcode  is_installed  capacity  numdocksavailable  \
# 0          44015          True      20.0                  5
# 979        21026          True      30.0                  5
# 978        13005          True      46.0                 24
# 977         2015          True      33.0                  1
# 976        18140          True      40.0                 37
# ...          ...           ...       ...                ...
# 485         9101          True      19.0                 16
# 484        16123          True      26.0                 16
# 483         6017          True      33.0                  4
# 481        17022          True      46.0                 41
# 1498        1002          True      22.0                 11
#
#       numbikesavailable  mechanical  ebike  is_renting  is_returning  \
# 0                    15           3     12        True          True
# 979                  25          10     15        True          True
# 978                  21          19      2        True          True
# 977                  31          16     15        True          True
# 976                   3           1      2        True          True
# ...                 ...         ...    ...         ...           ...
# 485                   3           1      2        True          True
# 484                  10           4      6        True          True
# 483                  27          21      6        True          True
# 481                   5           3      2        True          True
# 1498                 11           8      3        True          True
#
#                  duedate code_insee_commune       date  duedate_year  \
# 0    2024-08-19 09:03:07              94081 2024-08-19          2024
# 979  2024-08-19 09:04:15              92012 2024-08-19          2024
# 978  2024-08-19 09:04:37              75056 2024-08-19          2024
# 977  2024-08-19 09:04:23              75056 2024-08-19          2024
# 976  2024-08-19 08:58:08              75056 2024-08-19          2024
# ...                  ...                ...        ...           ...
# 485  2024-08-19 08:58:29              75056 2024-08-19          2024
# 484  2024-08-19 08:59:02              75056 2024-08-19          2024
# 483  2024-08-19 09:04:17              75056 2024-08-19          2024
# 481  2024-08-19 09:02:01              75056 2024-08-19          2024
# 1498 2024-08-19 09:03:48              75056 2024-08-19          2024
#
#       duedate_month  duedate_day  duedate_weekday  duedate_weekend  \
# 0                 8           19                0                0
# 979               8           19                0                0
# 978               8           19                0                0
# 977               8           19                0                0
# 976               8           19                0                0
# ...             ...          ...              ...              ...
# 485               8           19                0                0
# 484               8           19                0                0
# 483               8           19                0                0
# 481               8           19                0                0
# 1498              8           19                0                0
#
#      Description_ZoneA
# 0       Vacances d'Été
# 979     Vacances d'Été
# 978     Vacances d'Été
# 977     Vacances d'Été
# 976     Vacances d'Été
# ...                ...
# 485     Vacances d'Été
# 484     Vacances d'Été
# 483     Vacances d'Été
# 481     Vacances d'Été
# 1498    Vacances d'Été
#
# [1449 rows x 18 columns]
